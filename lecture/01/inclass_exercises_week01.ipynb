# %% [markdown]
# # Week 1 in-class exercises: numpy and matplotlib warm-up
#
# **ASTR 457, Thu Aug 27. Not collected, not graded.** Work solo or in pairs.
# These are finger exercises for the array manipulation and plotting you'll use in every lab.
# If you can do these comfortably, Lab 01 will hold no mechanical surprises.
#
# Make sure the kernel (top right) says `astr457` before you start.

# %% [markdown]
# ## 1. Indexing and reshaping
#
# Create `A = np.logspace(-3, 7, 200).reshape(10, 5, 4)`. Without printing the whole
# array, predict, then print, the values of `A[3, 0, 2]`, `A[5, 4, 1]`, and
# `A[-1, -1, -1]`. (What *must* the last one be, given what `logspace` does?)

# %%
import numpy as np

# your work here

# %% [markdown]
# ## 2. Boolean masking
#
# Given the matrix below, replace every element greater than 4 with the value 4,
# in one line, without a loop. (This is exactly how you'll clip, select, and flag
# data points all semester.)

# %%
B = np.array([[-2, 8, 10, 1], [17, 9, 2, 0], [1, 6, -4, 10], [3, 8, -9, 4]])

# your work here

# %% [markdown]
# ## 3. Slicing
#
# Build a 10×10 checkerboard of 1s and 0s (1 in the top-left corner) using only
# `np.zeros` and slice assignment, with no loops.

# %%
# your work here

# %% [markdown]
# ## 4. Load real data and plot it
#
# Load `data/demo_data.csv` (columns `t_days`, `rv_kms`, `sigma_rv_kms`, yes,
# the radial-velocity dataset from Tuesday's demo). Make a properly labeled
# errorbar plot: axis labels with units, a legend, and the six contaminated
# exposures I revealed on Tuesday plotted in a different color or marker. Hint:
# you now know the truth is rv = 3.2·t + 9.5, so a boolean mask on the size of
# the residual relative to `sigma_rv_kms` finds them.

# %%
import matplotlib.pyplot as plt

# your work here

# %% [markdown]
# ## 5. If you finish early: a 2-D surface
#
# Run the cell below, then visualize `z` with `plt.pcolormesh` (add a colorbar and
# axis labels). Then try a log color scale (`norm=matplotlib.colors.LogNorm()`).
# Which one actually shows you the structure?

# %%
rng = np.random.default_rng(457)
u = np.sort(rng.random(100))
v = np.sort(rng.random(100))
uu, vv = np.meshgrid(u, v)
z = np.exp(-(np.sqrt(uu) + np.sqrt(vv)) / 0.05)

# your plot here

# %% [markdown]
# ## Before you leave
#
# - Read `help/astro_conventions.md` in the repo before Lab 01.
# - Lab 01 posts Thu Sep 3 and is due Wed Sep 9 by Noon, submitted by pull
#   request from your fork (`help/git/sync_a_fork.md` if you get stuck).
